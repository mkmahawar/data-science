# %%
g = open("b.txt","r")
# print(g.read(20))
print(g.readline())
print(g.readline())
print(g.readline())
# for i in g:
#     print(i)
g.close()
# Out:
# hello my name is manish
#
# i am leaving from alwer
#
# hyyyy

# %%
g= open("b.txt",'w')
g.write("hello sir")
g.close()
g= open("b.txt",'r')
print(g.read())
# Out:
# hello sir

# %%
with open("m.txt","a") as file:
    file.write("hyyy i am good")
file.close()

# %%
with open("m.txt","w") as file:
    file.write("hyyy")
file.close()

# %%
    
with open("m.txt","x") as file:
    file.
